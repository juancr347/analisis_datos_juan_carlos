# %% [markdown]
# # Seaborn
#
# https://seaborn.pydata.org/
#
# https://github.com/mwaskom/seaborn-data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Displot

# %%
df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.sort_values('weight', ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 42   12.0          8         383.0       180.0    4955          11.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# ..    ...        ...           ...         ...     ...           ...
# 53   31.0          4          71.0        65.0    1773          19.0
# 345  35.1          4          81.0        60.0    1760          16.1
# 343  39.1          4          79.0        58.0    1755          16.9
# 144  31.0          4          76.0        52.0    1649          16.5
# 54   35.0          4          72.0        69.0    1613          18.0
#
#      model_year origin                      name
# 44           71    usa       pontiac safari (sw)
# ...

# %%
sns.displot(df["weight"])

# %%
sns.displot(df["weight"], kde=True)

# %%
sns.displot(df["weight"], bins=5)

# %%
df = sns.load_dataset("tips")
sns.displot(df, x="day")

# %%
sns.displot(df, x="day", shrink=.8)

# %%
sns.displot(df, x="size")

# %%
sns.displot(df, x="size", discrete=True)

# %%
df = sns.load_dataset("penguins")
sns.displot(df, x="flipper_length_mm")

# %%
sns.displot(df, x="flipper_length_mm", hue="species")

# %%
sns.displot(df, x="flipper_length_mm", col="sex")

# %%
'''
la densidad de probabilidad representa cuán comunes o raros
son los diferentes valores.

Los datos se suavizan en una única curva continua.

La curva muestra cuánto pesa cada valor en el conjunto de
datos.

Valores con una curva de densidad más alta son más comunes,
valores con una curva de densidad más baja son menos comunes

Eje y muestra la densidad: cuántos puntos tienes en una región, 
ajustada por el ancho de esa región.
'''

sns.displot(df, x="flipper_length_mm", kind="kde")

# %%
sns.displot(df, x="flipper_length_mm", hue="species", kind="kde")

# %%
sns.displot(df, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.displot(df, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# ## Histplot

# %%
df = sns.load_dataset("penguins")
sns.histplot(df["bill_length_mm"])
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(df["bill_depth_mm"])
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(df, x="bill_depth_mm")
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(df, x="bill_depth_mm", kde=True)
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(data=df, x="bill_depth_mm", bins=30)
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Count'>

# %% [markdown]
# ## Jointplot

# %%
df = sns.load_dataset("penguins")
sns.jointplot(data=df, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.jointplot(
    data=df,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
)

# %% [markdown]
# ## Kdeplot

# %%
df = sns.load_dataset("penguins")
sns.kdeplot(df["bill_length_mm"])
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='Density'>

# %% [markdown]
# ## Pairplot

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df)

# %%
df = sns.load_dataset("tips")
sns.pairplot(df)

# %%
sns.pairplot(df, hue="sex", palette="Reds")

# %%
sns.pairplot(df, hue="smoker", palette="viridis")

# %%
# CUIDADO con datasets grandes
# si hay muchas columnas y muchas filas el pairplot puede tardar bastante
df_sample = df.sample(100) # toma una muestra de forma aleatoria
df_sample.head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2

# %%
sns.pairplot(df_sample, hue="smoker", palette="viridis")

# %% [markdown]
# ## Relplot
#
# Equivalente a scatterplot pero más flexible

# %%
df = sns.load_dataset("tips")
sns.relplot(data=df, x="total_bill", y="tip")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="smoker", col="time")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="smoker", col="time", row="sex")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="smoker", col="time", size="size")

# %% [markdown]
# ## Scatterplot

# %%
df = sns.load_dataset("tips")
sns.scatterplot(data=df, x="total_bill", y="tip")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
# https://seaborn.pydata.org/tutorial/color_palettes.html
sns.scatterplot(data=df, x="total_bill", y="tip", hue="size", palette='viridis')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Ecdfplot
#
# Función acumulativa

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Va de 0 a 1 el eje y
# mapea cada valor a su percentil en la muestra 
sns.ecdfplot(data=df, x="bill_depth_mm")
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Proportion'>

# %%
df = sns.load_dataset("tips")
sns.ecdfplot(data=df, x="tip")
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Proportion'>

# %%
df = sns.load_dataset("titanic")
sns.ecdfplot(data=df, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Proportion'>

# %% [markdown]
# ## Lineplot

# %%
df = sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data=df, x="year", y="passengers", errorbar=None)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=df, x="year", y="passengers", hue="month")
# Out:
# <AxesSubplot: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=df, x="year", y="passengers", hue="month", palette="Paired")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## Rugplot

# %%
df = sns.load_dataset("tips")
sns.rugplot(df["total_bill"])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
sns.kdeplot(data=df, x="total_bill")
sns.rugplot(data=df, x="total_bill")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
sns.rugplot(data=df, x="total_bill", y="tip")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
sns.rugplot(data=df, x="total_bill", y="tip", height=.1)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Barplot

# %%
df = sns.load_dataset("tips")
sns.barplot(x="sex", y="total_bill", data=df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex", y="total_bill", data=df, estimator=np.cov) # mean() by default
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Countplot

# %%
df = sns.load_dataset("tips")
sns.countplot(x="sex", data=df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
ax = sns.countplot(x='sex', data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '157'), Text(0, 0, '87')]

# %% [markdown]
# ## Boxplot

# %%
df = sns.load_dataset("tips")
sns.boxplot(df['total_bill'])
# Out:
# <Axes: >

# %%
df = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df, hue="sex")
plt.legend(loc=2)

# %% [markdown]
# ## Violinplot

# %%
df = sns.load_dataset("tips")
sns.violinplot(x="day", y="total_bill", data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df, hue="sex", split=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Stripplot

# %%
df = sns.load_dataset("tips")
sns.stripplot(x="day", y="total_bill", data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=df, jitter=True, hue="sex", dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Swarmplot

# %%
df = sns.load_dataset("tips")
sns.swarmplot(x="day", y="total_bill", data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=df, hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=df, hue='sex', palette='viridis')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df)
sns.swarmplot(x="day", y="total_bill", data=df, color="white")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Heatmap

# %%
df = sns.load_dataset("tips")
df_corr = df.corr(numeric_only=True)
sns.heatmap(df_corr, annot=True, cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
df = sns.load_dataset("penguins")
df_corr = df.corr(numeric_only=True)
sns.heatmap(df_corr, annot=True, cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df_corr, annot=True, linewidth=.5, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
df = sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_pivot = df.pivot_table(index="month", columns="year", values="passengers")
df_pivot.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
sns.heatmap(df_pivot, cmap="viridis", linecolor="white", linewidth=1)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Clustermap

# %%
sns.clustermap(df_pivot, cmap="viridis", standard_scale=1)
